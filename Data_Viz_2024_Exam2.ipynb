# %% [markdown]
# <a href="https://colab.research.google.com/github/Natkitta252603/Python_dataviz2024/blob/main/Data_Viz_2024_Exam2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
crime_scene_report = pd.read_csv('/content/drive/MyDrive/Exam2/crime_scene_report.csv')
crime_scene_report
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
drivers= pd.read_csv('/content/drive/MyDrive/Exam2/drivers_license.csv')
drivers
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
event_checkin = pd.read_csv('/content/drive/MyDrive/Exam2/facebook_event_checkin.csv')
event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
check_in = pd.read_csv('/content/drive/MyDrive/Exam2/get_fit_now_check_in.csv')
check_in
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
member = pd.read_csv('/content/drive/MyDrive/Exam2/get_fit_now_member.csv')
member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
income = pd.read_csv('/content/drive/MyDrive/Exam2/income.csv')
income
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
interview = pd.read_csv('/content/drive/MyDrive/Exam2/interview.csv')
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
person = pd.read_csv('/content/drive/MyDrive/Exam2/person.csv')
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %% [markdown]
# #สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City

# %%
# prompt: กรองข้อมูล crime_scene_report เพื่อหาคดีฆาตกรรมในวันที่ 15 มกราคม 2018 ที่เมือง SQL City

# ดึงข้อมูล crime_scene_report.csv
crime_scene_report_df = pd.read_csv('/content/drive/MyDrive/Exam2/crime_scene_report.csv')

# เลือกเฉพาะ type murder and date 20180115 ที่ SQL City
select_data = crime_scene_report_df[(crime_scene_report_df['type'] == 'murder') & (crime_scene_report_df['date'] == 20180115) & (crime_scene_report_df['city'] == 'SQL City')]

# แสดงผลลัพธ์
select_data
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %% [markdown]
# จากข้อมูลที่ได้ ภาพจากกล้องวงจรปิดพบว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบน "Northwestern Dr" พยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบนถนนแฟรงคลิน

# %% [markdown]
# หาข้อมูลของพยานคนที่ 1

# %%
# prompt: พยานคนที่ 1 คนที่อาศัยอยู่บ้านหลังสุดท้ายบน 'Northwestern Dr'

# หาบ้านหลังสุดท้ายบนถนน Northwestern Dr
person[person["address_street_name"] == "Northwestern Dr"].sort_values("address_number", ascending = False).iloc[0]
# Out:
# id                               14887
# name                    Morty Schapiro
# license_id                      118009
# address_number                    4919
# address_street_name    Northwestern Dr
# ssn                          111564949
# Name: 499, dtype: object

# %%
# prompt: สอบสวนพยานคนที่1 จาก interview

# สอบสวนพยานคนที่ 1 จาก interview
interview[interview['person_id'] == 14887]
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...

# %% [markdown]
# จากคำให้การพยานคนที่1 ฉันได้ยินเสียงปืนแล้วก็เห็นชายคนหนึ่งวิ่งออกไป เขามีกระเป๋า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าขึ้นต้นด้วย "48Z" เฉพาะสมาชิกระดับโกลด์เท่านั้นที่มีถุงเหล่านั้น ชายคนนั้นขึ้นรถที่มีเลขทะเบียน "H42W"

# %% [markdown]
# หาข้อมูลของพยานคนที่ 2

# %%
# prompt: หาข้อมูลAnnabel อาศัยอยู่บนถนนFranklin Ave

# หาข้อมูลของพยานคนที่ 2
witness2 = person[(person['address_street_name'] == 'Franklin Ave') & (person['name'].str.contains('Annabel'))]
witness2
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
# prompt: สอบสวน Annabel จาก interview

# สอบสวน Annabel
interview[interview['person_id'] == 16371]
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# Annabel ให้การว่า ฉันเห็นการฆาตกรรมเกิดขึ้น และฉันก็จำฆาตกรได้จากยิมของฉันตอนที่ฉันกำลังออกกำลังกายเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม

# %%
# prompt: หาคนที่ check in วันที่ 9 มกราคม
check_in[check_in['check_in_date']==20180109]
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %% [markdown]
# จากคำให้การพยานคนที่1 ที่บอกว่าเขาเห็นชายคนนั้นมีกระเป๋าสมาชิกขึ้นต้นด้วย 48Z ซึ่งจากผลที่ออกมาพบว่ามี 2 คน ที่เลขสมาชิกขึ้นต้นด้วย 48Z

# %%
#หา2คนนั้นที่มี id ขึ้นต้นด้วย 48Z และอยู่ระดับ gold
import pandas as pd
get_fit_now_member = pd.read_csv('/content/drive/MyDrive/Exam2/get_fit_now_member.csv')
gold_member = get_fit_now_member[get_fit_now_member['membership_status'] == 'gold']
gold_member = gold_member[gold_member['id'].str.startswith('48Z')]
gold_member.head()
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
# prompt: หารถที่มีป้ายทะเบียน "H42W"

# หาข้อมูลรถที่ประกอบด้วย "H42W"
drivers[drivers['plate_number'].str.contains('H42W')]
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
#กาว่าไอดี183779 คือใคร
person[person_df.license_id == 183779]
# Out:
#          id            name  license_id  address_number address_street_name  \
# 7578  78193  Maxine Whitely      183779             110             Fisk Rd
#
#             ssn
# 7578  137882671

# %%
person_df[person_df.license_id == 423327]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %%
person_df[person_df.license_id == 664760]
# Out:
#          id            name  license_id  address_number address_street_name  \
# 4664  51739  Tushar Chandra      664760             312              Phi St
#
#             ssn
# 4664  137882671

# %% [markdown]
# จากข้อมูลของพยาน คนที่เข้าค่ายเป็นฆาตกรมากที่สุดคือ Jeremy Bowers เพราะเขาคือบุคคลที่เข้าใช้ยิมในวันที่9 มกรา มีเลขกระเป๋า ป้ายทะเบียนรถตรงตามที่พยานให้การ

# %% [markdown]
# สอบสวน Jeremy Bowers

# %%
interview[interview['person_id'] == 67318]
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# จากคำให้การ ฉันถูกจ้างโดยผู้หญิงที่มีเงินมากมาย ฉันไม่รู้ชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5'5" (65") หรือ 5'7" (67") เธอมีผมสีแดงและเธอขับรถ Tesla Model S ฉันรู้ว่าเธอเข้าร่วม SQL Symphony Concert 3 ครั้งในเดือนธันวาคม 2017
