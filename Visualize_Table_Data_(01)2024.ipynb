# %% [markdown]
# <a href="https://colab.research.google.com/github/Natkitta252603/Python_dataviz2024/blob/main/Visualize_Table_Data_(01)2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name'); #Name คือใส่ชื่อคอลัมม์ที่ต้องการให้แสดงเป็นสี

# %% [markdown]
# ## ปรับ parameter: color

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=('#FFD700', '#C0C0C0', '#CD7F32')) #html color
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=((1,0.8,0), (0,0.7,0), (0.6,0,1))) #rgb value (r,g,b) | r,g,b -> [0,1]
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=('r', 'g', 'b')) #ตัวย่อของสี R G B W C M Y K แดง เขียว น้ำเงิน ขาว ฟ้า ม่วง เหลือง ดำ
# Out:
# <Axes: >

# %% [markdown]
# ## ปรับ parameter: colormap

# %%
pd.plotting.parallel_coordinates(df, 'Name', colormap='Pastel2')
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name', colormap='tab10')
# Out:
# <Axes: >

# %% [markdown]
# # เริ่ม Matplotlib

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### แปลง data จาก pandas dataframe เป็น numpy array

# %%
np_data = df.iloc[:,:-1].to_numpy()
np_data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# # Visualize array data ด้วย pixel

# %%
import matplotlib

# %%
matplotlib.rcParams['figure.figsize']=[15,15] #กำหนดขนาดของ figure

plt.imshow(np_data[:50,:],interpolation='nearest')

# %%
plt.imshow(np_data[50:100,:],interpolation='nearest',cmap='plasma') #mุกฟังก์ใช้cmap

# %% [markdown]
# # การใช้ subplot
# คือการเอากราฟมาเรียงข้างกันเพื่อให้ดูง่าย

# %%
plt.subplot(1,3,1)  # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(np_data[:50,:],interpolation='nearest',cmap='magma')

plt.subplot(1,3,2)
plt.imshow(np_data[50:100,:],interpolation='nearest',cmap='magma')

plt.subplot(1,3,3)
plt.imshow(np_data[100:150,:],interpolation='nearest',cmap='magma') #สีเข้มคือเลขน้อยสีสว่างคือเลขมาก

# %%
plt.imshow(np_data[:10,:],interpolation='nearest',cmap='magma',alpha = 1 ) #อัลฟ่าคือบอกความเข้มของสี ยิ่งค่าน้อยยิ่งเข้ม
